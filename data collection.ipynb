# %% [markdown]
# # PUBMED data

# %%
from Bio import Entrez
import time
from pathlib import Path

# Set your email (required by NCBI)
Entrez.email = "divyanshr141@email.com"

# Output folder to save abstracts
output_dir = Path("pubmed_abstracts")
output_dir.mkdir(exist_ok=True)

def fetch_pubmed_abstracts(query, max_results=10):
    try:
        search_handle = Entrez.esearch(db="pubmed", term=query, retmax=max_results)
        search_results = Entrez.read(search_handle)
        id_list = search_results["IdList"]
        if not id_list:
            return f"No results found for query: {query}"

        fetch_handle = Entrez.efetch(db="pubmed", id=",".join(id_list), rettype="abstract", retmode="text")
        data = fetch_handle.read()
        return data
    except Exception as e:
        return f"Error fetching data for query '{query}': {e}"

# Conditions and allergies
conditions = [
    "high blood pressure", "diabetes", "heart disease", "celiac disease",
    "obesity", "IBS", "lactose intolerance", "arthritis", "asthma", "eczema"
]
allergies = ["dairy", "gluten", "nuts", "shellfish", "soy", "eggs", "wheat", "corn"]

# Loop through all combinations
for condition in conditions:
    for allergy in allergies:
        query = f"{condition} {allergy} allergy"
        print(f"\n--- Fetching for: {query} ---")
        abstracts = fetch_pubmed_abstracts(query, max_results=10)

        # Save abstracts to a .txt file
        filename = f"{condition}_{allergy}_allergy.txt".replace(" ", "_").lower()
        filepath = output_dir / filename
        with open(filepath, "w", encoding="utf-8") as f:
            f.write(abstracts)

        print(f"✅ Saved to: {filepath}")
        time.sleep(1)  # Respectful delay
# Out:
# --- Fetching for: high blood pressure dairy allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_dairy_allergy.txt
#
# --- Fetching for: high blood pressure gluten allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_gluten_allergy.txt
#
# --- Fetching for: high blood pressure nuts allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_nuts_allergy.txt
#
# --- Fetching for: high blood pressure shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_shellfish_allergy.txt
#
# --- Fetching for: high blood pressure soy allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_soy_allergy.txt
#
# --- Fetching for: high blood pressure eggs allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_eggs_allergy.txt
#
# --- Fetching for: high blood pressure wheat allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_wheat_allergy.txt
#
# --- Fetching for: high blood pressure corn allergy ---
# ✅ Saved to: pubmed_abstracts\high_blood_pressure_corn_allergy.txt
#
# --- Fetching for: diabetes dairy allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_dairy_allergy.txt
#
# --- Fetching for: diabetes gluten allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_gluten_allergy.txt
#
# --- Fetching for: diabetes nuts allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_nuts_allergy.txt
#
# --- Fetching for: diabetes shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_shellfish_allergy.txt
#
# --- Fetching for: diabetes soy allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_soy_allergy.txt
#
# --- Fetching for: diabetes eggs allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_eggs_allergy.txt
#
# --- Fetching for: diabetes wheat allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_wheat_allergy.txt
#
# --- Fetching for: diabetes corn allergy ---
# ✅ Saved to: pubmed_abstracts\diabetes_corn_allergy.txt
#
# --- Fetching for: heart disease dairy allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_dairy_allergy.txt
#
# --- Fetching for: heart disease gluten allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_gluten_allergy.txt
#
# --- Fetching for: heart disease nuts allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_nuts_allergy.txt
#
# --- Fetching for: heart disease shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_shellfish_allergy.txt
#
# --- Fetching for: heart disease soy allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_soy_allergy.txt
#
# --- Fetching for: heart disease eggs allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_eggs_allergy.txt
#
# --- Fetching for: heart disease wheat allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_wheat_allergy.txt
#
# --- Fetching for: heart disease corn allergy ---
# ✅ Saved to: pubmed_abstracts\heart_disease_corn_allergy.txt
#
# --- Fetching for: celiac disease dairy allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_dairy_allergy.txt
#
# --- Fetching for: celiac disease gluten allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_gluten_allergy.txt
#
# --- Fetching for: celiac disease nuts allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_nuts_allergy.txt
#
# --- Fetching for: celiac disease shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_shellfish_allergy.txt
#
# --- Fetching for: celiac disease soy allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_soy_allergy.txt
#
# --- Fetching for: celiac disease eggs allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_eggs_allergy.txt
#
# --- Fetching for: celiac disease wheat allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_wheat_allergy.txt
#
# --- Fetching for: celiac disease corn allergy ---
# ✅ Saved to: pubmed_abstracts\celiac_disease_corn_allergy.txt
#
# --- Fetching for: obesity dairy allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_dairy_allergy.txt
#
# --- Fetching for: obesity gluten allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_gluten_allergy.txt
#
# --- Fetching for: obesity nuts allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_nuts_allergy.txt
#
# --- Fetching for: obesity shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_shellfish_allergy.txt
#
# --- Fetching for: obesity soy allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_soy_allergy.txt
#
# --- Fetching for: obesity eggs allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_eggs_allergy.txt
#
# --- Fetching for: obesity wheat allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_wheat_allergy.txt
#
# --- Fetching for: obesity corn allergy ---
# ✅ Saved to: pubmed_abstracts\obesity_corn_allergy.txt
#
# --- Fetching for: IBS dairy allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_dairy_allergy.txt
#
# --- Fetching for: IBS gluten allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_gluten_allergy.txt
#
# --- Fetching for: IBS nuts allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_nuts_allergy.txt
#
# --- Fetching for: IBS shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_shellfish_allergy.txt
#
# --- Fetching for: IBS soy allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_soy_allergy.txt
#
# --- Fetching for: IBS eggs allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_eggs_allergy.txt
#
# --- Fetching for: IBS wheat allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_wheat_allergy.txt
#
# --- Fetching for: IBS corn allergy ---
# ✅ Saved to: pubmed_abstracts\ibs_corn_allergy.txt
#
# --- Fetching for: lactose intolerance dairy allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_dairy_allergy.txt
#
# --- Fetching for: lactose intolerance gluten allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_gluten_allergy.txt
#
# --- Fetching for: lactose intolerance nuts allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_nuts_allergy.txt
#
# --- Fetching for: lactose intolerance shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_shellfish_allergy.txt
#
# --- Fetching for: lactose intolerance soy allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_soy_allergy.txt
#
# --- Fetching for: lactose intolerance eggs allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_eggs_allergy.txt
#
# --- Fetching for: lactose intolerance wheat allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_wheat_allergy.txt
#
# --- Fetching for: lactose intolerance corn allergy ---
# ✅ Saved to: pubmed_abstracts\lactose_intolerance_corn_allergy.txt
#
# --- Fetching for: arthritis dairy allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_dairy_allergy.txt
#
# --- Fetching for: arthritis gluten allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_gluten_allergy.txt
#
# --- Fetching for: arthritis nuts allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_nuts_allergy.txt
#
# --- Fetching for: arthritis shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_shellfish_allergy.txt
#
# --- Fetching for: arthritis soy allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_soy_allergy.txt
#
# --- Fetching for: arthritis eggs allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_eggs_allergy.txt
#
# --- Fetching for: arthritis wheat allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_wheat_allergy.txt
#
# --- Fetching for: arthritis corn allergy ---
# ✅ Saved to: pubmed_abstracts\arthritis_corn_allergy.txt
#
# --- Fetching for: asthma dairy allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_dairy_allergy.txt
#
# --- Fetching for: asthma gluten allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_gluten_allergy.txt
#
# --- Fetching for: asthma nuts allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_nuts_allergy.txt
#
# --- Fetching for: asthma shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_shellfish_allergy.txt
#
# --- Fetching for: asthma soy allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_soy_allergy.txt
#
# --- Fetching for: asthma eggs allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_eggs_allergy.txt
#
# --- Fetching for: asthma wheat allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_wheat_allergy.txt
#
# --- Fetching for: asthma corn allergy ---
# ✅ Saved to: pubmed_abstracts\asthma_corn_allergy.txt
#
# --- Fetching for: eczema dairy allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_dairy_allergy.txt
#
# --- Fetching for: eczema gluten allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_gluten_allergy.txt
#
# --- Fetching for: eczema nuts allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_nuts_allergy.txt
#
# --- Fetching for: eczema shellfish allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_shellfish_allergy.txt
#
# --- Fetching for: eczema soy allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_soy_allergy.txt
#
# --- Fetching for: eczema eggs allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_eggs_allergy.txt
#
# --- Fetching for: eczema wheat allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_wheat_allergy.txt
#
# --- Fetching for: eczema corn allergy ---
# ✅ Saved to: pubmed_abstracts\eczema_corn_allergy.txt

# %% [markdown]
# # FDC data

# %%
apikeyfdc= 'ApdGkZpttgPvMkfMVMLkyTmClmEhy7n77axbi3YQ'

# %%
import requests
import json
from pathlib import Path

def fetch_fdc_foods(query, api_key, max_results=5):
    url = "https://api.nal.usda.gov/fdc/v1/foods/search"
    params = {
        "api_key": api_key,
        "query": query,
        "pageSize": max_results,
        "dataType": ["Foundation", "SR Legacy", "Survey (FNDDS)"]
    }

    response = requests.get(url, params=params)
    try:
        response.raise_for_status()
        return response.json()
    except Exception as e:
        return {"error": str(e)}

# Replace with your actual API key
api_key = apikeyfdc

# Define diseases and allergies
conditions = [
    "high blood pressure", "diabetes", "heart disease", "celiac disease",
    "obesity", "IBS", "lactose intolerance", "arthritis", "asthma", "eczema"
]

allergies = [
    "dairy", "gluten", "nuts", "shellfish", "soy", "eggs", "wheat", "corn"
]

# Create output folder
output_dir = Path("fdc_data")
output_dir.mkdir(exist_ok=True)

# Loop through all combinations of condition and allergy
for condition in conditions:
    for allergy in allergies:
        query = f"{condition} {allergy}"
        print(f"\n🔍 Querying FDC: {query}")
        result = fetch_fdc_foods(query, api_key)

        # Save the result
        filename = f"{condition}_{allergy}".replace(" ", "_").lower() + ".txt"
        filepath = output_dir / filename
        with open(filepath, "w", encoding="utf-8") as f:
            json.dump(result, f, indent=2)

        print(f"✅ Saved to: {filepath}")
# Out:
# 🔍 Querying FDC: high blood pressure dairy
# ✅ Saved to: fdc_data\high_blood_pressure_dairy.txt
#
# 🔍 Querying FDC: high blood pressure gluten
# ✅ Saved to: fdc_data\high_blood_pressure_gluten.txt
#
# 🔍 Querying FDC: high blood pressure nuts
# ✅ Saved to: fdc_data\high_blood_pressure_nuts.txt
#
# 🔍 Querying FDC: high blood pressure shellfish
# ✅ Saved to: fdc_data\high_blood_pressure_shellfish.txt
#
# 🔍 Querying FDC: high blood pressure soy
# ✅ Saved to: fdc_data\high_blood_pressure_soy.txt
#
# 🔍 Querying FDC: high blood pressure eggs
# ✅ Saved to: fdc_data\high_blood_pressure_eggs.txt
#
# 🔍 Querying FDC: high blood pressure wheat
# ✅ Saved to: fdc_data\high_blood_pressure_wheat.txt
#
# 🔍 Querying FDC: high blood pressure corn
# ✅ Saved to: fdc_data\high_blood_pressure_corn.txt
#
# 🔍 Querying FDC: diabetes dairy
# ✅ Saved to: fdc_data\diabetes_dairy.txt
#
# 🔍 Querying FDC: diabetes gluten
# ✅ Saved to: fdc_data\diabetes_gluten.txt
#
# 🔍 Querying FDC: diabetes nuts
# ✅ Saved to: fdc_data\diabetes_nuts.txt
#
# 🔍 Querying FDC: diabetes shellfish
# ✅ Saved to: fdc_data\diabetes_shellfish.txt
#
# 🔍 Querying FDC: diabetes soy
# ✅ Saved to: fdc_data\diabetes_soy.txt
#
# 🔍 Querying FDC: diabetes eggs
# ✅ Saved to: fdc_data\diabetes_eggs.txt
#
# 🔍 Querying FDC: diabetes wheat
# ✅ Saved to: fdc_data\diabetes_wheat.txt
#
# 🔍 Querying FDC: diabetes corn
# ✅ Saved to: fdc_data\diabetes_corn.txt
#
# 🔍 Querying FDC: heart disease dairy
# ✅ Saved to: fdc_data\heart_disease_dairy.txt
#
# 🔍 Querying FDC: heart disease gluten
# ✅ Saved to: fdc_data\heart_disease_gluten.txt
#
# 🔍 Querying FDC: heart disease nuts
# ✅ Saved to: fdc_data\heart_disease_nuts.txt
#
# 🔍 Querying FDC: heart disease shellfish
# ✅ Saved to: fdc_data\heart_disease_shellfish.txt
#
# 🔍 Querying FDC: heart disease soy
# ✅ Saved to: fdc_data\heart_disease_soy.txt
#
# 🔍 Querying FDC: heart disease eggs
# ✅ Saved to: fdc_data\heart_disease_eggs.txt
#
# 🔍 Querying FDC: heart disease wheat
# ✅ Saved to: fdc_data\heart_disease_wheat.txt
#
# 🔍 Querying FDC: heart disease corn
# ✅ Saved to: fdc_data\heart_disease_corn.txt
#
# 🔍 Querying FDC: celiac disease dairy
# ✅ Saved to: fdc_data\celiac_disease_dairy.txt
#
# 🔍 Querying FDC: celiac disease gluten
# ✅ Saved to: fdc_data\celiac_disease_gluten.txt
#
# 🔍 Querying FDC: celiac disease nuts
# ✅ Saved to: fdc_data\celiac_disease_nuts.txt
#
# 🔍 Querying FDC: celiac disease shellfish
# ✅ Saved to: fdc_data\celiac_disease_shellfish.txt
#
# 🔍 Querying FDC: celiac disease soy
# ✅ Saved to: fdc_data\celiac_disease_soy.txt
#
# 🔍 Querying FDC: celiac disease eggs
# ✅ Saved to: fdc_data\celiac_disease_eggs.txt
#
# 🔍 Querying FDC: celiac disease wheat
# ✅ Saved to: fdc_data\celiac_disease_wheat.txt
#
# 🔍 Querying FDC: celiac disease corn
# ✅ Saved to: fdc_data\celiac_disease_corn.txt
#
# 🔍 Querying FDC: obesity dairy
# ✅ Saved to: fdc_data\obesity_dairy.txt
#
# 🔍 Querying FDC: obesity gluten
# ✅ Saved to: fdc_data\obesity_gluten.txt
#
# 🔍 Querying FDC: obesity nuts
# ✅ Saved to: fdc_data\obesity_nuts.txt
#
# 🔍 Querying FDC: obesity shellfish
# ✅ Saved to: fdc_data\obesity_shellfish.txt
#
# 🔍 Querying FDC: obesity soy
# ✅ Saved to: fdc_data\obesity_soy.txt
#
# 🔍 Querying FDC: obesity eggs
# ✅ Saved to: fdc_data\obesity_eggs.txt
#
# 🔍 Querying FDC: obesity wheat
# ✅ Saved to: fdc_data\obesity_wheat.txt
#
# 🔍 Querying FDC: obesity corn
# ✅ Saved to: fdc_data\obesity_corn.txt
#
# 🔍 Querying FDC: IBS dairy
# ✅ Saved to: fdc_data\ibs_dairy.txt
#
# 🔍 Querying FDC: IBS gluten
# ✅ Saved to: fdc_data\ibs_gluten.txt
#
# 🔍 Querying FDC: IBS nuts
# ✅ Saved to: fdc_data\ibs_nuts.txt
#
# 🔍 Querying FDC: IBS shellfish
# ✅ Saved to: fdc_data\ibs_shellfish.txt
#
# 🔍 Querying FDC: IBS soy
# ✅ Saved to: fdc_data\ibs_soy.txt
#
# 🔍 Querying FDC: IBS eggs
# ✅ Saved to: fdc_data\ibs_eggs.txt
#
# 🔍 Querying FDC: IBS wheat
# ✅ Saved to: fdc_data\ibs_wheat.txt
#
# 🔍 Querying FDC: IBS corn
# ✅ Saved to: fdc_data\ibs_corn.txt
#
# 🔍 Querying FDC: lactose intolerance dairy
# ✅ Saved to: fdc_data\lactose_intolerance_dairy.txt
#
# 🔍 Querying FDC: lactose intolerance gluten
# ✅ Saved to: fdc_data\lactose_intolerance_gluten.txt
#
# 🔍 Querying FDC: lactose intolerance nuts
# ✅ Saved to: fdc_data\lactose_intolerance_nuts.txt
#
# 🔍 Querying FDC: lactose intolerance shellfish
# ✅ Saved to: fdc_data\lactose_intolerance_shellfish.txt
#
# 🔍 Querying FDC: lactose intolerance soy
# ✅ Saved to: fdc_data\lactose_intolerance_soy.txt
#
# 🔍 Querying FDC: lactose intolerance eggs
# ✅ Saved to: fdc_data\lactose_intolerance_eggs.txt
#
# 🔍 Querying FDC: lactose intolerance wheat
# ✅ Saved to: fdc_data\lactose_intolerance_wheat.txt
#
# 🔍 Querying FDC: lactose intolerance corn
# ✅ Saved to: fdc_data\lactose_intolerance_corn.txt
#
# 🔍 Querying FDC: arthritis dairy
# ✅ Saved to: fdc_data\arthritis_dairy.txt
#
# 🔍 Querying FDC: arthritis gluten
# ✅ Saved to: fdc_data\arthritis_gluten.txt
#
# 🔍 Querying FDC: arthritis nuts
# ✅ Saved to: fdc_data\arthritis_nuts.txt
#
# 🔍 Querying FDC: arthritis shellfish
# ✅ Saved to: fdc_data\arthritis_shellfish.txt
#
# 🔍 Querying FDC: arthritis soy
# ✅ Saved to: fdc_data\arthritis_soy.txt
#
# 🔍 Querying FDC: arthritis eggs
# ✅ Saved to: fdc_data\arthritis_eggs.txt
#
# 🔍 Querying FDC: arthritis wheat
# ✅ Saved to: fdc_data\arthritis_wheat.txt
#
# 🔍 Querying FDC: arthritis corn
# ✅ Saved to: fdc_data\arthritis_corn.txt
#
# 🔍 Querying FDC: asthma dairy
# ✅ Saved to: fdc_data\asthma_dairy.txt
#
# 🔍 Querying FDC: asthma gluten
# ✅ Saved to: fdc_data\asthma_gluten.txt
#
# 🔍 Querying FDC: asthma nuts
# ✅ Saved to: fdc_data\asthma_nuts.txt
#
# 🔍 Querying FDC: asthma shellfish
# ✅ Saved to: fdc_data\asthma_shellfish.txt
#
# 🔍 Querying FDC: asthma soy
# ✅ Saved to: fdc_data\asthma_soy.txt
#
# 🔍 Querying FDC: asthma eggs
# ✅ Saved to: fdc_data\asthma_eggs.txt
#
# 🔍 Querying FDC: asthma wheat
# ✅ Saved to: fdc_data\asthma_wheat.txt
#
# 🔍 Querying FDC: asthma corn
# ✅ Saved to: fdc_data\asthma_corn.txt
#
# 🔍 Querying FDC: eczema dairy
# ✅ Saved to: fdc_data\eczema_dairy.txt
#
# 🔍 Querying FDC: eczema gluten
# ✅ Saved to: fdc_data\eczema_gluten.txt
#
# 🔍 Querying FDC: eczema nuts
# ✅ Saved to: fdc_data\eczema_nuts.txt
#
# 🔍 Querying FDC: eczema shellfish
# ✅ Saved to: fdc_data\eczema_shellfish.txt
#
# 🔍 Querying FDC: eczema soy
# ✅ Saved to: fdc_data\eczema_soy.txt
#
# 🔍 Querying FDC: eczema eggs
# ✅ Saved to: fdc_data\eczema_eggs.txt
#
# 🔍 Querying FDC: eczema wheat
# ✅ Saved to: fdc_data\eczema_wheat.txt
#
# 🔍 Querying FDC: eczema corn
# ✅ Saved to: fdc_data\eczema_corn.txt

# %% [markdown]
# # EATRIGHT data

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from pathlib import Path
import time
import json

def scrape_eatright_selenium(condition, allergy, max_results=5):
    query = f"{condition} {allergy}".replace(" ", "%20")
    search_url = f"https://www.eatright.org/search-results?search={query}"

    options = Options()
    options.headless = True
    options.add_argument("--disable-gpu")
    options.add_argument("--no-sandbox")

    results = []

    try:
        driver = webdriver.Chrome(options=options)
        driver.get(search_url)

        time.sleep(3)  # wait for JS to load content

        articles = driver.find_elements(By.CSS_SELECTOR, ".search-results__item")

        for article in articles[:max_results]:
            try:
                link_elem = article.find_element(By.TAG_NAME, "a")
                title = link_elem.text.strip()
                link = link_elem.get_attribute("href")
                results.append({"title": title, "link": link})
            except Exception as e:
                results.append({"error": f"Error extracting article: {e}"})

        driver.quit()

    except Exception as e:
        results.append({"error": f"Selenium crash or session error: {e}"})

    return results if results else [{"note": "No articles found."}]

# === Main ===
if __name__ == "__main__":
    conditions = [
        "high blood pressure", "diabetes", "heart disease", "celiac disease",
        "obesity", "IBS", "lactose intolerance", "arthritis", "asthma", "eczema"
    ]
    allergies = ["dairy", "gluten", "nuts", "shellfish", "soy", "eggs", "wheat", "corn"]

    output_dir = Path("eatright_articles")
    output_dir.mkdir(exist_ok=True)

    for condition in conditions:
        for allergy in allergies:
            print(f"\n🔍 Scraping: {condition} + {allergy}")
            articles = scrape_eatright_selenium(condition, allergy)

            filename = f"{condition}_{allergy}".replace(" ", "_").lower() + ".txt"
            filepath = output_dir / filename
            with open(filepath, "w", encoding="utf-8") as f:
                json.dump(articles, f, indent=2)

            print(f"✅ Saved: {filepath}")
# Out:
# 🔍 Scraping: high blood pressure + dairy
# ✅ Saved: eatright_articles\high_blood_pressure_dairy.txt
#
# 🔍 Scraping: high blood pressure + gluten
# ✅ Saved: eatright_articles\high_blood_pressure_gluten.txt
#
# 🔍 Scraping: high blood pressure + nuts
# ✅ Saved: eatright_articles\high_blood_pressure_nuts.txt
#
# 🔍 Scraping: high blood pressure + shellfish
# ✅ Saved: eatright_articles\high_blood_pressure_shellfish.txt
#
# 🔍 Scraping: high blood pressure + soy
# ✅ Saved: eatright_articles\high_blood_pressure_soy.txt
#
# 🔍 Scraping: high blood pressure + eggs
# ✅ Saved: eatright_articles\high_blood_pressure_eggs.txt
#
# 🔍 Scraping: high blood pressure + wheat
# ✅ Saved: eatright_articles\high_blood_pressure_wheat.txt
#
# 🔍 Scraping: high blood pressure + corn
# ✅ Saved: eatright_articles\high_blood_pressure_corn.txt
#
# 🔍 Scraping: diabetes + dairy
# ✅ Saved: eatright_articles\diabetes_dairy.txt
#
# 🔍 Scraping: diabetes + gluten
# ✅ Saved: eatright_articles\diabetes_gluten.txt
#
# 🔍 Scraping: diabetes + nuts
# ✅ Saved: eatright_articles\diabetes_nuts.txt
#
# 🔍 Scraping: diabetes + shellfish
# ✅ Saved: eatright_articles\diabetes_shellfish.txt
#
# 🔍 Scraping: diabetes + soy
# ✅ Saved: eatright_articles\diabetes_soy.txt
#
# 🔍 Scraping: diabetes + eggs
# ✅ Saved: eatright_articles\diabetes_eggs.txt
#
# 🔍 Scraping: diabetes + wheat
# ✅ Saved: eatright_articles\diabetes_wheat.txt
#
# 🔍 Scraping: diabetes + corn
# ✅ Saved: eatright_articles\diabetes_corn.txt
#
# 🔍 Scraping: heart disease + dairy
# ✅ Saved: eatright_articles\heart_disease_dairy.txt
#
# 🔍 Scraping: heart disease + gluten
# ✅ Saved: eatright_articles\heart_disease_gluten.txt
#
# 🔍 Scraping: heart disease + nuts
# ✅ Saved: eatright_articles\heart_disease_nuts.txt
#
# 🔍 Scraping: heart disease + shellfish
# ✅ Saved: eatright_articles\heart_disease_shellfish.txt
#
# 🔍 Scraping: heart disease + soy
# ✅ Saved: eatright_articles\heart_disease_soy.txt
#
# 🔍 Scraping: heart disease + eggs
# ✅ Saved: eatright_articles\heart_disease_eggs.txt
#
# 🔍 Scraping: heart disease + wheat
# ✅ Saved: eatright_articles\heart_disease_wheat.txt
#
# 🔍 Scraping: heart disease + corn
# ✅ Saved: eatright_articles\heart_disease_corn.txt
#
# 🔍 Scraping: celiac disease + dairy
# ✅ Saved: eatright_articles\celiac_disease_dairy.txt
#
# 🔍 Scraping: celiac disease + gluten
# ✅ Saved: eatright_articles\celiac_disease_gluten.txt
#
# 🔍 Scraping: celiac disease + nuts
# ✅ Saved: eatright_articles\celiac_disease_nuts.txt
#
# 🔍 Scraping: celiac disease + shellfish
# ✅ Saved: eatright_articles\celiac_disease_shellfish.txt
#
# 🔍 Scraping: celiac disease + soy
# ✅ Saved: eatright_articles\celiac_disease_soy.txt
#
# 🔍 Scraping: celiac disease + eggs
# ✅ Saved: eatright_articles\celiac_disease_eggs.txt
#
# 🔍 Scraping: celiac disease + wheat
# ✅ Saved: eatright_articles\celiac_disease_wheat.txt
#
# 🔍 Scraping: celiac disease + corn
# ✅ Saved: eatright_articles\celiac_disease_corn.txt
#
# 🔍 Scraping: obesity + dairy
# ✅ Saved: eatright_articles\obesity_dairy.txt
#
# 🔍 Scraping: obesity + gluten
# ✅ Saved: eatright_articles\obesity_gluten.txt
#
# 🔍 Scraping: obesity + nuts
# ✅ Saved: eatright_articles\obesity_nuts.txt
#
# 🔍 Scraping: obesity + shellfish
# ✅ Saved: eatright_articles\obesity_shellfish.txt
#
# 🔍 Scraping: obesity + soy
# ✅ Saved: eatright_articles\obesity_soy.txt
#
# 🔍 Scraping: obesity + eggs
# ✅ Saved: eatright_articles\obesity_eggs.txt
#
# 🔍 Scraping: obesity + wheat
# ✅ Saved: eatright_articles\obesity_wheat.txt
#
# 🔍 Scraping: obesity + corn
# ✅ Saved: eatright_articles\obesity_corn.txt
#
# 🔍 Scraping: IBS + dairy
# ✅ Saved: eatright_articles\ibs_dairy.txt
#
# 🔍 Scraping: IBS + gluten
# ✅ Saved: eatright_articles\ibs_gluten.txt
#
# 🔍 Scraping: IBS + nuts
# ✅ Saved: eatright_articles\ibs_nuts.txt
#
# 🔍 Scraping: IBS + shellfish
# ✅ Saved: eatright_articles\ibs_shellfish.txt
#
# 🔍 Scraping: IBS + soy
# ✅ Saved: eatright_articles\ibs_soy.txt
#
# 🔍 Scraping: IBS + eggs
# ✅ Saved: eatright_articles\ibs_eggs.txt
#
# 🔍 Scraping: IBS + wheat
# ✅ Saved: eatright_articles\ibs_wheat.txt
#
# 🔍 Scraping: IBS + corn
# ✅ Saved: eatright_articles\ibs_corn.txt
#
# 🔍 Scraping: lactose intolerance + dairy
# ✅ Saved: eatright_articles\lactose_intolerance_dairy.txt
#
# 🔍 Scraping: lactose intolerance + gluten
# ✅ Saved: eatright_articles\lactose_intolerance_gluten.txt
#
# 🔍 Scraping: lactose intolerance + nuts
# ✅ Saved: eatright_articles\lactose_intolerance_nuts.txt
#
# 🔍 Scraping: lactose intolerance + shellfish
# ✅ Saved: eatright_articles\lactose_intolerance_shellfish.txt
#
# 🔍 Scraping: lactose intolerance + soy
# ✅ Saved: eatright_articles\lactose_intolerance_soy.txt
#
# 🔍 Scraping: lactose intolerance + eggs
# ✅ Saved: eatright_articles\lactose_intolerance_eggs.txt
#
# 🔍 Scraping: lactose intolerance + wheat
# ✅ Saved: eatright_articles\lactose_intolerance_wheat.txt
#
# 🔍 Scraping: lactose intolerance + corn
# ✅ Saved: eatright_articles\lactose_intolerance_corn.txt
#
# 🔍 Scraping: arthritis + dairy
# ✅ Saved: eatright_articles\arthritis_dairy.txt
#
# 🔍 Scraping: arthritis + gluten
# ✅ Saved: eatright_articles\arthritis_gluten.txt
#
# 🔍 Scraping: arthritis + nuts
# ✅ Saved: eatright_articles\arthritis_nuts.txt
#
# 🔍 Scraping: arthritis + shellfish
# ✅ Saved: eatright_articles\arthritis_shellfish.txt
#
# 🔍 Scraping: arthritis + soy
# ✅ Saved: eatright_articles\arthritis_soy.txt
#
# 🔍 Scraping: arthritis + eggs
# ✅ Saved: eatright_articles\arthritis_eggs.txt
#
# 🔍 Scraping: arthritis + wheat
# ✅ Saved: eatright_articles\arthritis_wheat.txt
#
# 🔍 Scraping: arthritis + corn
# ✅ Saved: eatright_articles\arthritis_corn.txt
#
# 🔍 Scraping: asthma + dairy
# ✅ Saved: eatright_articles\asthma_dairy.txt
#
# 🔍 Scraping: asthma + gluten
# ✅ Saved: eatright_articles\asthma_gluten.txt
#
# 🔍 Scraping: asthma + nuts
# ✅ Saved: eatright_articles\asthma_nuts.txt
#
# 🔍 Scraping: asthma + shellfish
# ✅ Saved: eatright_articles\asthma_shellfish.txt
#
# 🔍 Scraping: asthma + soy
# ✅ Saved: eatright_articles\asthma_soy.txt
#
# 🔍 Scraping: asthma + eggs
# ✅ Saved: eatright_articles\asthma_eggs.txt
#
# 🔍 Scraping: asthma + wheat
# ✅ Saved: eatright_articles\asthma_wheat.txt
#
# 🔍 Scraping: asthma + corn
# ✅ Saved: eatright_articles\asthma_corn.txt
#
# 🔍 Scraping: eczema + dairy
# ✅ Saved: eatright_articles\eczema_dairy.txt
#
# 🔍 Scraping: eczema + gluten
# ✅ Saved: eatright_articles\eczema_gluten.txt
#
# 🔍 Scraping: eczema + nuts
# ✅ Saved: eatright_articles\eczema_nuts.txt
#
# 🔍 Scraping: eczema + shellfish
# ✅ Saved: eatright_articles\eczema_shellfish.txt
#
# 🔍 Scraping: eczema + soy
# ✅ Saved: eatright_articles\eczema_soy.txt
#
# 🔍 Scraping: eczema + eggs
# ✅ Saved: eatright_articles\eczema_eggs.txt
#
# 🔍 Scraping: eczema + wheat
# ✅ Saved: eatright_articles\eczema_wheat.txt
#
# 🔍 Scraping: eczema + corn
# ✅ Saved: eatright_articles\eczema_corn.txt

# %% [markdown]
# # Harvard data

# %%
import requests
from bs4 import BeautifulSoup
from pathlib import Path
import time

def scrape_harvard_nutrition(query):
    base_url = "https://nutritionsource.hsph.harvard.edu"
    search_url = f"{base_url}/?s={query.replace(' ', '+')}"
    headers = {'User-Agent': 'Mozilla/5.0'}

    try:
        res = requests.get(search_url, headers=headers)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, "html.parser")

        results = []
        for article in soup.select("article"):
            title_tag = article.find("h2")
            if title_tag:
                link_tag = title_tag.find("a")
                if link_tag and link_tag.get("href"):
                    link = link_tag["href"]
                    if link.startswith("/"):
                        link = base_url + link
                    title = title_tag.get_text(strip=True)
                    results.append({"title": title, "link": link})
        return results

    except requests.RequestException as e:
        return [{"error": f"Request failed: {e}"}]
    except Exception as e:
        return [{"error": f"Parsing failed: {e}"}]

def extract_article_content(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    try:
        res = requests.get(url, headers=headers)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, "html.parser")

        content_div = soup.find("div", class_="entry-content") or soup.find("main")
        if not content_div:
            return "⚠️ Could not locate main content."

        paragraphs = content_div.find_all("p")
        article_text = "\n".join(p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True))
        return article_text if article_text else "⚠️ No readable paragraphs found."

    except requests.RequestException as e:
        return f"❌ Request failed: {e}"
    except Exception as e:
        return f"❌ Error parsing article: {e}"

# === Main Script ===
if __name__ == "__main__":
    conditions = [
        "high blood pressure", "diabetes", "heart disease", "celiac disease",
        "obesity", "IBS", "lactose intolerance", "arthritis", "asthma", "eczema"
    ]
    allergies = ["dairy", "gluten", "nuts", "shellfish", "soy", "eggs", "wheat", "corn"]

    output_dir = Path("harvard_articles")
    output_dir.mkdir(exist_ok=True)

    for condition in conditions:
        for allergy in allergies:
            query = f"{condition} {allergy}"
            print(f"\n🔍 Searching for: {query}")
            results = scrape_harvard_nutrition(query)

            filename = f"{condition}_{allergy}".replace(" ", "_").lower() + ".txt"
            filepath = output_dir / filename

            with open(filepath, "w", encoding="utf-8") as f:
                for item in results:
                    if "error" in item:
                        f.write(f"❌ Error: {item['error']}\n")
                        print("❌", item["error"])
                        continue

                    f.write(f"🔗 {item['title']}\n{item['link']}\n\n")
                    content = extract_article_content(item["link"])
                    f.write(content + "\n\n" + "="*80 + "\n\n")
                    print(f"✅ {item['title']}")
                    time.sleep(1)  # Respectful delay

            print(f"💾 Saved to: {filepath}")
# Out:
# 🔍 Searching for: high blood pressure dairy
# ✅ Dairy
# ✅ Avocados
# ✅ Iodine
# ✅ Aquatic Foods
# ✅ Cheese
# ✅ Milk
# ✅ Calcium
# ✅ Choline
# ✅ Magnesium
# ✅ Processed Foods and Health
# 💾 Saved to: harvard_articles\high_blood_pressure_dairy.txt
#
# 🔍 Searching for: high blood pressure gluten
# ✅ Precision Nutrition
# ✅ Rice
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Oats
# ✅ Diet Reviews
# ✅ Whole Grains
# ✅ Protein
# 💾 Saved to: harvard_articles\high_blood_pressure_gluten.txt
#
# 🔍 Searching for: high blood pressure nuts
# ✅ Electrolyte Drinks
# ✅ WHO releases updated guidelines on defining healthy diets
# ✅ Chloride
# ✅ Copper
# ✅ Diet Review: MIND Diet
# ✅ Avocados
# ✅ Dairy
# ✅ Cheese
# ✅ Milk
# ✅ Calcium
# 💾 Saved to: harvard_articles\high_blood_pressure_nuts.txt
#
# 🔍 Searching for: high blood pressure shellfish
# ✅ Copper
# ✅ Iodine
# ✅ Aquatic Foods
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Fish: Friend or Foe?
# ✅ Ask the Expert: Healthy Fats
# 💾 Saved to: harvard_articles\high_blood_pressure_shellfish.txt
#
# 🔍 Searching for: high blood pressure soy
# ✅ Straight Talk About Soy
# ✅ Chloride
# ✅ Dairy
# ✅ Milk
# ✅ Calcium
# ✅ Legumes and Pulses
# ✅ Magnesium
# ✅ Processed Foods and Health
# ✅ Potassium
# ✅ Oats
# 💾 Saved to: harvard_articles\high_blood_pressure_soy.txt
#
# 🔍 Searching for: high blood pressure eggs
# ✅ Electrolyte Drinks
# ✅ Avocados
# ✅ Iodine
# ✅ Aquatic Foods
# ✅ Cheese
# ✅ Choline
# ✅ Potassium
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# ✅ Chia Seeds
# 💾 Saved to: harvard_articles\high_blood_pressure_eggs.txt
#
# 🔍 Searching for: high blood pressure wheat
# ✅ Copper
# ✅ Processed Foods and Health
# ✅ Rice
# ✅ Bananas
# ✅ Oats
# ✅ Whole Grains
# ✅ Sleep
# ✅ Healthy Eating Plate
# ✅ Protein
# ✅ Fiber
# 💾 Saved to: harvard_articles\high_blood_pressure_wheat.txt
#
# 🔍 Searching for: high blood pressure corn
# ✅ Precision Nutrition
# ✅ Niacin – Vitamin B3
# ✅ Water
# ✅ Energy Drinks
# ✅ Tea
# ✅ Processed Foods and Health
# ✅ Potassium
# ✅ Coffee
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# ✅ Diet Review: DASH
# 💾 Saved to: harvard_articles\high_blood_pressure_corn.txt
#
# 🔍 Searching for: diabetes dairy
# ✅ Dairy
# ✅ Simple Steps to Preventing Diabetes
# ✅ Seaweed
# ✅ Oral Health
# ✅ Avocados
# ✅ Phosphorus
# ✅ Workout Supplements
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Aquatic Foods
# ✅ Dietary Guidelines for Americans 2020 released
# 💾 Saved to: harvard_articles\diabetes_dairy.txt
#
# 🔍 Searching for: diabetes gluten
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Healthy Living Guide 2020/2021
# ✅ Precision Nutrition
# ✅ Rice
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Almonds
# ✅ Oats
# ✅ Superfoods or Superhype?
# 💾 Saved to: harvard_articles\diabetes_gluten.txt
#
# 🔍 Searching for: diabetes nuts
# ✅ Healthy plant-based diet linked with substantially lower type 2 diabetes risk
# ✅ Simple Steps to Preventing Diabetes
# ✅ Nuts for the Heart
# ✅ Electrolyte Drinks
# ✅ Preventing Obesity
# ✅ WHO releases updated guidelines on defining healthy diets
# ✅ Chloride
# ✅ Manganese
# ✅ Oral Health
# ✅ Diet Review: MIND Diet
# 💾 Saved to: harvard_articles\diabetes_nuts.txt
#
# 🔍 Searching for: diabetes shellfish
# ✅ Manganese
# ✅ Aquatic Foods
# ✅ Selenium
# ✅ Thiamin – Vitamin B1
# ✅ Vitamin B12
# ✅ Are Anti-Nutrients Harmful?
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Antioxidants
# ✅ Ask the Expert: Healthy Fats
# 💾 Saved to: harvard_articles\diabetes_shellfish.txt
#
# 🔍 Searching for: diabetes soy
# ✅ Chloride
# ✅ Manganese
# ✅ Oral Health
# ✅ Workout Supplements
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Dairy
# ✅ Milk
# ✅ Ask the Expert: The role of diet and nutritional supplements during COVID-19
# ✅ Mushrooms
# ✅ Legumes and Pulses
# 💾 Saved to: harvard_articles\diabetes_soy.txt
#
# 🔍 Searching for: diabetes eggs
# ✅ Eggs
# ✅ Electrolyte Drinks
# ✅ Preventing Obesity
# ✅ Oral Health
# ✅ Avocados
# ✅ Workout Supplements
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Aquatic Foods
# ✅ Chromium
# ✅ Dietary Guidelines for Americans 2020 released
# 💾 Saved to: harvard_articles\diabetes_eggs.txt
#
# 🔍 Searching for: diabetes wheat
# ✅ Preventing Obesity
# ✅ Phosphorus
# ✅ Tips for a Healthy Summer Picnic
# ✅ Selenium
# ✅ Mushrooms
# ✅ Packing a Healthy Lunchbox
# ✅ Processed Foods and Health
# ✅ Lectins
# ✅ Are Anti-Nutrients Harmful?
# ✅ Rice
# 💾 Saved to: harvard_articles\diabetes_wheat.txt
#
# 🔍 Searching for: diabetes corn
# ✅ Simple Steps to Preventing Diabetes
# ✅ Oral Health
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ COVID-19 and Obesity
# ✅ Precision Nutrition
# ✅ Niacin – Vitamin B3
# ✅ Tips for a Healthy Summer Picnic
# ✅ Water
# ✅ Sports Drinks
# ✅ Energy Drinks
# 💾 Saved to: harvard_articles\diabetes_corn.txt
#
# 🔍 Searching for: heart disease dairy
# ✅ Dairy
# ✅ Saturated fat, regardless of type, linked with increased heart disease risk
# ✅ Study sheds light on dairy fat and cardiovascular disease risk
# ✅ How is heart disease risk affected when saturated fat is replaced by other nutrients?
# ✅ Dietary Fat and Disease
# ✅ Preventing Heart Disease
# ✅ Dietary fat and heart disease study is seriously misleading
# ✅ Seaweed
# ✅ Molybdenum
# ✅ Oral Health
# 💾 Saved to: harvard_articles\heart_disease_dairy.txt
#
# 🔍 Searching for: heart disease gluten
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Understanding Food Labels
# ✅ Rice
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Almonds
# ✅ Oats
# ✅ Superfoods or Superhype?
# ✅ Quinoa
# 💾 Saved to: harvard_articles\heart_disease_gluten.txt
#
# 🔍 Searching for: heart disease nuts
# ✅ Study sheds light on dairy fat and cardiovascular disease risk
# ✅ Healthy Heart Score uses lifestyle behaviors to estimate cardiovascular disease risk
# ✅ Dietary linoleic acid and risk of coronary heart disease
# ✅ Dietary Fat and Disease
# ✅ Preventing Heart Disease
# ✅ Dietary fat and heart disease study is seriously misleading
# ✅ Nuts for the Heart
# ✅ Electrolyte Drinks
# ✅ Probiotics for Gut Health
# ✅ Preventing Obesity
# 💾 Saved to: harvard_articles\heart_disease_nuts.txt
#
# 🔍 Searching for: heart disease shellfish
# ✅ Manganese
# ✅ Copper
# ✅ Iodine
# ✅ Aquatic Foods
# ✅ Understanding Food Labels
# ✅ Selenium
# ✅ Zinc
# ✅ Thiamin – Vitamin B1
# ✅ Vitamin B12
# ✅ Are Anti-Nutrients Harmful?
# 💾 Saved to: harvard_articles\heart_disease_shellfish.txt
#
# 🔍 Searching for: heart disease soy
# ✅ Straight Talk About Soy
# ✅ Dietary linoleic acid and risk of coronary heart disease
# ✅ Probiotics for Gut Health
# ✅ Manganese
# ✅ Oral Health
# ✅ Understanding Food Labels
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Dairy
# ✅ Milk
# ✅ Calcium
# 💾 Saved to: harvard_articles\heart_disease_soy.txt
#
# 🔍 Searching for: heart disease eggs
# ✅ Eggs and cholesterol back in the spotlight in new JAMA study
# ✅ Study sheds light on dairy fat and cardiovascular disease risk
# ✅ Preventing Heart Disease
# ✅ Eggs
# ✅ Electrolyte Drinks
# ✅ Preventing Obesity
# ✅ Oral Health
# ✅ Avocados
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Iodine
# 💾 Saved to: harvard_articles\heart_disease_eggs.txt
#
# 🔍 Searching for: heart disease wheat
# ✅ Probiotics for Gut Health
# ✅ Preventing Obesity
# ✅ Molybdenum
# ✅ Copper
# ✅ Phosphorus
# ✅ Understanding Food Labels
# ✅ Tips for a Healthy Summer Picnic
# ✅ Selenium
# ✅ Mushrooms
# ✅ Processed Foods and Health
# 💾 Saved to: harvard_articles\heart_disease_wheat.txt
#
# 🔍 Searching for: heart disease corn
# ✅ Healthy Heart Score uses lifestyle behaviors to estimate cardiovascular disease risk
# ✅ Dietary linoleic acid and risk of coronary heart disease
# ✅ Preventing Heart Disease
# ✅ Oral Health
# ✅ Understanding Food Labels
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ COVID-19 and Obesity
# ✅ Niacin – Vitamin B3
# ✅ Tips for a Healthy Summer Picnic
# ✅ Energy Drinks
# 💾 Saved to: harvard_articles\heart_disease_corn.txt
#
# 🔍 Searching for: celiac disease dairy
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Magnesium
# ✅ Vitamin B12
# ✅ Bananas
# ✅ Oats
# ✅ Frequently Asked Questions
# ✅ Protein
# ✅ Vitamin A
# 💾 Saved to: harvard_articles\celiac_disease_dairy.txt
#
# 🔍 Searching for: celiac disease gluten
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Precision Nutrition
# ✅ Oats
# ✅ Superfoods or Superhype?
# ✅ Diet Reviews
# ✅ Quinoa
# ✅ Whole Grains
# ✅ Protein
# 💾 Saved to: harvard_articles\celiac_disease_gluten.txt
#
# 🔍 Searching for: celiac disease nuts
# ✅ Copper
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Magnesium
# ✅ Bananas
# ✅ Oats
# ✅ Diet Reviews
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Quinoa
# ✅ Folate (Folic Acid) – Vitamin B9
# ✅ Protein
# 💾 Saved to: harvard_articles\celiac_disease_nuts.txt
#
# 🔍 Searching for: celiac disease shellfish
# ✅ Copper
# ✅ Thiamin – Vitamin B1
# ✅ Vitamin B12
# 💾 Saved to: harvard_articles\celiac_disease_shellfish.txt
#
# 🔍 Searching for: celiac disease soy
# ✅ Magnesium
# ✅ Vitamin B12
# ✅ Oats
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Protein
# ✅ Vitamin E
# 💾 Saved to: harvard_articles\celiac_disease_soy.txt
#
# 🔍 Searching for: celiac disease eggs
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Vitamin B12
# ✅ Superfoods or Superhype?
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Frequently Asked Questions
# ✅ Folate (Folic Acid) – Vitamin B9
# ✅ Protein
# ✅ Vitamin A
# ✅ Vitamin E
# 💾 Saved to: harvard_articles\celiac_disease_eggs.txt
#
# 🔍 Searching for: celiac disease wheat
# ✅ Copper
# ✅ Bananas
# ✅ Oats
# ✅ Superfoods or Superhype?
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Whole Grains
# ✅ Protein
# ✅ Vitamin E
# 💾 Saved to: harvard_articles\celiac_disease_wheat.txt
#
# 🔍 Searching for: celiac disease corn
# ✅ Precision Nutrition
# ✅ Superfoods or Superhype?
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Quinoa
# ✅ Whole Grains
# ✅ Folate (Folic Acid) – Vitamin B9
# ✅ Protein
# 💾 Saved to: harvard_articles\celiac_disease_corn.txt
#
# 🔍 Searching for: obesity dairy
# ✅ Seaweed
# ✅ Oral Health
# ✅ Phosphorus
# ✅ Clean Eating
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Cheese
# ✅ Mindful Eating
# ✅ Choline
# ✅ Ask the Expert: Popular plant-based meat alternatives
# 💾 Saved to: harvard_articles\obesity_dairy.txt
#
# 🔍 Searching for: obesity gluten
# ✅ Diet Review: Gluten-Free for Weight Loss
# ✅ Gluten: A Benefit or Harm to the Body?
# ✅ Clean Eating
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Precision Nutrition
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Almonds
# ✅ Superfoods or Superhype?
# ✅ Protein
# 💾 Saved to: harvard_articles\obesity_gluten.txt
#
# 🔍 Searching for: obesity nuts
# ✅ Preventing Obesity
# ✅ Nuts for the Heart
# ✅ Electrolyte Drinks
# ✅ Oral Health
# ✅ Diet Review: MIND Diet
# ✅ Phosphorus
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Cravings
# ✅ The Science of Snacking
# ✅ Dietary Guidelines for Americans 2020 released
# 💾 Saved to: harvard_articles\obesity_nuts.txt
#
# 🔍 Searching for: obesity shellfish
# ✅ Plate and the Planet
# ✅ Diet Review: Paleo Diet for Weight Loss
# ✅ Ask the Expert: Healthy Fats
# 💾 Saved to: harvard_articles\obesity_shellfish.txt
#
# 🔍 Searching for: obesity soy
# ✅ Oral Health
# ✅ Cravings
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Strategies for Eating Well on a Budget
# ✅ Legumes and Pulses
# ✅ Ask the Expert: Popular plant-based meat alternatives
# ✅ Packing a Healthy Lunchbox
# ✅ Processed Foods and Health
# ✅ Lectins
# ✅ Plate and the Planet
# 💾 Saved to: harvard_articles\obesity_soy.txt
#
# 🔍 Searching for: obesity eggs
# ✅ Preventing Obesity
# ✅ Electrolyte Drinks
# ✅ Oral Health
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Chromium
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Cheese
# ✅ Choline
# ✅ Strategies for Eating Well on a Budget
# ✅ Packing a Healthy Lunchbox
# 💾 Saved to: harvard_articles\obesity_eggs.txt
#
# 🔍 Searching for: obesity wheat
# ✅ Preventing Obesity
# ✅ Phosphorus
# ✅ Clean Eating
# ✅ The Science of Snacking
# ✅ Strategies for Eating Well on a Budget
# ✅ Packing a Healthy Lunchbox
# ✅ Processed Foods and Health
# ✅ Lectins
# ✅ Plate and the Planet
# ✅ Almonds
# 💾 Saved to: harvard_articles\obesity_wheat.txt
#
# 🔍 Searching for: obesity corn
# ✅ COVID-19 and Obesity
# ✅ Healthy Food Environment
# ✅ Oral Health
# ✅ Cravings
# ✅ The Science of Snacking
# ✅ Dietary Guidelines for Americans 2020 released
# ✅ Precision Nutrition
# ✅ Strategies for Eating Well on a Budget
# ✅ Water
# ✅ Sports Drinks
# 💾 Saved to: harvard_articles\obesity_corn.txt
#
# 🔍 Searching for: IBS dairy
# ✅ Aquatic Foods
# ✅ Understanding Food Labels
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# ✅ Dark Chocolate
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\ibs_dairy.txt
#
# 🔍 Searching for: IBS gluten
# ✅ Understanding Food Labels
# 💾 Saved to: harvard_articles\ibs_gluten.txt
#
# 🔍 Searching for: IBS nuts
# ✅ Probiotics for Gut Health
# ✅ Understanding Food Labels
# ✅ Lectins
# ✅ Swap out red meat for healthier meats
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# ✅ Dark Chocolate
# 💾 Saved to: harvard_articles\ibs_nuts.txt
#
# 🔍 Searching for: IBS shellfish
# ✅ Aquatic Foods
# ✅ Understanding Food Labels
# ✅ Thiamin – Vitamin B1
# 💾 Saved to: harvard_articles\ibs_shellfish.txt
#
# 🔍 Searching for: IBS soy
# ✅ Probiotics for Gut Health
# ✅ Understanding Food Labels
# ✅ Lectins
# 💾 Saved to: harvard_articles\ibs_soy.txt
#
# 🔍 Searching for: IBS eggs
# ✅ Aquatic Foods
# ✅ Understanding Food Labels
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\ibs_eggs.txt
#
# 🔍 Searching for: IBS wheat
# ✅ Probiotics for Gut Health
# ✅ Understanding Food Labels
# ✅ Lectins
# 💾 Saved to: harvard_articles\ibs_wheat.txt
#
# 🔍 Searching for: IBS corn
# ✅ Understanding Food Labels
# ✅ Diet Review: Ketogenic Diet for Weight Loss
# 💾 Saved to: harvard_articles\ibs_corn.txt
#
# 🔍 Searching for: lactose intolerance dairy
# ✅ Dairy
# ✅ Cheese
# ✅ Milk
# ✅ Calcium
# ✅ Riboflavin – Vitamin B2
# ✅ Diet Review: DASH
# ✅ Yogurt
# ✅ Frequently Asked Questions
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\lactose_intolerance_dairy.txt
#
# 🔍 Searching for: lactose intolerance gluten
# ✅ Precision Nutrition
# 💾 Saved to: harvard_articles\lactose_intolerance_gluten.txt
#
# 🔍 Searching for: lactose intolerance nuts
# ✅ Dairy
# ✅ Cheese
# ✅ Milk
# ✅ Calcium
# ✅ Riboflavin – Vitamin B2
# ✅ Diet Review: DASH
# ✅ Yogurt
# 💾 Saved to: harvard_articles\lactose_intolerance_nuts.txt
#
# 🔍 Searching for: lactose intolerance shellfish
# 💾 Saved to: harvard_articles\lactose_intolerance_shellfish.txt
#
# 🔍 Searching for: lactose intolerance soy
# ✅ Dairy
# ✅ Milk
# ✅ Calcium
# ✅ Yogurt
# 💾 Saved to: harvard_articles\lactose_intolerance_soy.txt
#
# 🔍 Searching for: lactose intolerance eggs
# ✅ Cheese
# ✅ Riboflavin – Vitamin B2
# ✅ Frequently Asked Questions
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\lactose_intolerance_eggs.txt
#
# 🔍 Searching for: lactose intolerance wheat
# 💾 Saved to: harvard_articles\lactose_intolerance_wheat.txt
#
# 🔍 Searching for: lactose intolerance corn
# ✅ Precision Nutrition
# ✅ Diet Review: DASH
# 💾 Saved to: harvard_articles\lactose_intolerance_corn.txt
#
# 🔍 Searching for: arthritis dairy
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Collagen
# ✅ Pantothenic Acid – Vitamin B5
# ✅ Yogurt
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\arthritis_dairy.txt
#
# 🔍 Searching for: arthritis gluten
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Whole Grains
# 💾 Saved to: harvard_articles\arthritis_gluten.txt
#
# 🔍 Searching for: arthritis nuts
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Collagen
# ✅ Pantothenic Acid – Vitamin B5
# ✅ Selenium
# ✅ Iron
# ✅ Lectins
# ✅ Yogurt
# ✅ Research Roundup
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# ✅ Ask the expert: Omega-3 fatty acids
# 💾 Saved to: harvard_articles\arthritis_nuts.txt
#
# 🔍 Searching for: arthritis shellfish
# ✅ Collagen
# ✅ Selenium
# 💾 Saved to: harvard_articles\arthritis_shellfish.txt
#
# 🔍 Searching for: arthritis soy
# ✅ Collagen
# ✅ Lectins
# ✅ Yogurt
# ✅ Research Roundup
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# ✅ Ask the expert: Omega-3 fatty acids
# 💾 Saved to: harvard_articles\arthritis_soy.txt
#
# 🔍 Searching for: arthritis eggs
# ✅ Diet Review: Anti-Inflammatory Diet
# ✅ Collagen
# ✅ Pantothenic Acid – Vitamin B5
# ✅ Selenium
# ✅ Vitamin D
# 💾 Saved to: harvard_articles\arthritis_eggs.txt
#
# 🔍 Searching for: arthritis wheat
# ✅ Selenium
# ✅ Lectins
# ✅ Whole Grains
# 💾 Saved to: harvard_articles\arthritis_wheat.txt
#
# 🔍 Searching for: arthritis corn
# ✅ Whole Grains
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# ✅ Ask the expert: Omega-3 fatty acids
# 💾 Saved to: harvard_articles\arthritis_corn.txt
#
# 🔍 Searching for: asthma dairy
# ✅ Aquatic Foods
# 💾 Saved to: harvard_articles\asthma_dairy.txt
#
# 🔍 Searching for: asthma gluten
# ✅ Whole Grains
# 💾 Saved to: harvard_articles\asthma_gluten.txt
#
# 🔍 Searching for: asthma nuts
# ✅ Nickel
# 💾 Saved to: harvard_articles\asthma_nuts.txt
#
# 🔍 Searching for: asthma shellfish
# ✅ Aquatic Foods
# 💾 Saved to: harvard_articles\asthma_shellfish.txt
#
# 🔍 Searching for: asthma soy
# ✅ Nickel
# 💾 Saved to: harvard_articles\asthma_soy.txt
#
# 🔍 Searching for: asthma eggs
# ✅ Aquatic Foods
# 💾 Saved to: harvard_articles\asthma_eggs.txt
#
# 🔍 Searching for: asthma wheat
# ✅ Whole Grains
# 💾 Saved to: harvard_articles\asthma_wheat.txt
#
# 🔍 Searching for: asthma corn
# ✅ Whole Grains
# 💾 Saved to: harvard_articles\asthma_corn.txt
#
# 🔍 Searching for: eczema dairy
# ✅ Oats
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# 💾 Saved to: harvard_articles\eczema_dairy.txt
#
# 🔍 Searching for: eczema gluten
# ✅ Oats
# 💾 Saved to: harvard_articles\eczema_gluten.txt
#
# 🔍 Searching for: eczema nuts
# ✅ Zinc
# ✅ Oats
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# 💾 Saved to: harvard_articles\eczema_nuts.txt
#
# 🔍 Searching for: eczema shellfish
# ✅ Zinc
# 💾 Saved to: harvard_articles\eczema_shellfish.txt
#
# 🔍 Searching for: eczema soy
# ✅ Oats
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# 💾 Saved to: harvard_articles\eczema_soy.txt
#
# 🔍 Searching for: eczema eggs
# 💾 Saved to: harvard_articles\eczema_eggs.txt
#
# 🔍 Searching for: eczema wheat
# ✅ Oats
# 💾 Saved to: harvard_articles\eczema_wheat.txt
#
# 🔍 Searching for: eczema corn
# ✅ Omega-3 Fatty Acids: An Essential Contribution
# 💾 Saved to: harvard_articles\eczema_corn.txt
